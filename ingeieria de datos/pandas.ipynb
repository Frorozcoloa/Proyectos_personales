# %%
import pandas as pd

series_test = pd.Series([100,200,300])
series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test2 = pd.Series({1999:48,
                         2000: 65,
                         2001:89})
series_test2
# Out:
# 1999    48
# 2000    65
# 2001    89
# dtype: int64

# %%
frame_test = pd.DataFrame({1999: [74, 38, 39],
                          2000: [34, 32, 32],
                          2001: [23, 39, 23]})
frame_test
# Out:
#    1999  2000  2001
# 0    74    34    23
# 1    38    32    39
# 2    39    32    23

# %%
frame_test2 = pd.DataFrame([[74, 38, 39],
                         [34, 32, 32],
                         [23, 39, 23]], columns=[1999,2000,2001])
frame_test2
# Out:
#    1999  2000  2001
# 0    74    38    39
# 1    34    32    32
# 2    23    39    23

# %%
covid_colombia = pd.read_csv('C:res/Casos_positivos_de_COVID-19_en_Colombia.csv')

# %%
pd.options.display.max_rows = 10
covid_colombia
# Out:
#     ID de caso    Fecha de notificación  Codigo DIVIPOLA  \
# 0          693  2020-03-28T00:00:00.000            66001
# 1          810  2020-03-24T00:00:00.000            52835
# 2         1197  2020-03-26T00:00:00.000            66001
# 3         1597  2020-04-03T00:00:00.000             8758
# 4         1727  2020-03-31T00:00:00.000            23001
# ..         ...                      ...              ...
# 8         3502  2020-04-12T00:00:00.000            11001
# 9         3513  2020-04-11T00:00:00.000            11001
# 10        3679  2020-04-10T00:00:00.000            11001
# 11        3707  2020-04-06T00:00:00.000            11001
# 12        3794  2020-04-20T00:00:00.000             5088
#
#      Ciudad de ubicación Departamento o Distrito     atención  Edad Sexo  \
# 0                Pereira                Risaralda        Casa     6    F
# 1   San Andrés de Tumaco                   Nariño  Recuperado     6    M
# ...

# %%
#  dictionary like

covid_colombia['ID de caso']
# Out:
# 0      693
# 1      810
# 2     1197
# 3     1597
# 4     1727
#       ...
# 8     3502
# 9     3513
# 10    3679
# 11    3707
# 12    3794
# Name: ID de caso, Length: 13, dtype: int64

# %%
covid_colombia[['ID de caso', 'Fecha de notificación']]
# Out:
#     ID de caso    Fecha de notificación
# 0          693  2020-03-28T00:00:00.000
# 1          810  2020-03-24T00:00:00.000
# 2         1197  2020-03-26T00:00:00.000
# 3         1597  2020-04-03T00:00:00.000
# 4         1727  2020-03-31T00:00:00.000
# ..         ...                      ...
# 8         3502  2020-04-12T00:00:00.000
# 9         3513  2020-04-11T00:00:00.000
# 10        3679  2020-04-10T00:00:00.000
# 11        3707  2020-04-06T00:00:00.000
# 12        3794  2020-04-20T00:00:00.000
#
# [13 rows x 2 columns]

# %%
#Numpy like
covid_colombia.iloc[1:8]
# Out:
#    ID de caso    Fecha de notificación  Codigo DIVIPOLA   Ciudad de ubicación  \
# 1         810  2020-03-24T00:00:00.000            52835  San Andrés de Tumaco
# 2        1197  2020-03-26T00:00:00.000            66001               Pereira
# 3        1597  2020-04-03T00:00:00.000             8758               Soledad
# 4        1727  2020-03-31T00:00:00.000            23001              Montería
# 5        2149  2020-03-28T00:00:00.000            52835  San Andrés de Tumaco
# 6        2461  2020-04-04T00:00:00.000            76520               Palmira
# 7        3404  2020-04-14T00:00:00.000            25513                 Pacho
#
#   Departamento o Distrito     atención  Edad Sexo         Tipo Estado  \
# 1                   Nariño  Recuperado     6    M    Importado   Leve
# 2                Risaralda  Recuperado     6    M  Relacionado   Leve
# 3                Atlántico        Casa     6    M  Relacionado   Leve
# ...

# %%
covid_colombia.iloc[2]['ID de caso']
# Out:
# 1197

# %%
covid_colombia.iloc[:3,3]
# Out:
# 0                 Pereira
# 1    San Andrés de Tumaco
# 2                 Pereira
# Name: Ciudad de ubicación, dtype: object

# %%
covid_colombia.loc[: ,'ID de caso':'Fecha de notificación']
# Out:
#     ID de caso    Fecha de notificación
# 0          693  2020-03-28T00:00:00.000
# 1          810  2020-03-24T00:00:00.000
# 2         1197  2020-03-26T00:00:00.000
# 3         1597  2020-04-03T00:00:00.000
# 4         1727  2020-03-31T00:00:00.000
# ..         ...                      ...
# 8         3502  2020-04-12T00:00:00.000
# 9         3513  2020-04-11T00:00:00.000
# 10        3679  2020-04-10T00:00:00.000
# 11        3707  2020-04-06T00:00:00.000
# 12        3794  2020-04-20T00:00:00.000
#
# [13 rows x 2 columns]

# %%
covid_colombia['ID'] = 'colombia'

# %%
covid_colombia
# Out:
#     ID de caso    Fecha de notificación  Codigo DIVIPOLA  \
# 0          693  2020-03-28T00:00:00.000            66001
# 1          810  2020-03-24T00:00:00.000            52835
# 2         1197  2020-03-26T00:00:00.000            66001
# 3         1597  2020-04-03T00:00:00.000             8758
# 4         1727  2020-03-31T00:00:00.000            23001
# ..         ...                      ...              ...
# 8         3502  2020-04-12T00:00:00.000            11001
# 9         3513  2020-04-11T00:00:00.000            11001
# 10        3679  2020-04-10T00:00:00.000            11001
# 11        3707  2020-04-06T00:00:00.000            11001
# 12        3794  2020-04-20T00:00:00.000             5088
#
#      Ciudad de ubicación Departamento o Distrito     atención  Edad Sexo  \
# 0                Pereira                Risaralda        Casa     6    F
# 1   San Andrés de Tumaco                   Nariño  Recuperado     6    M
# ...

# %%
covid_colombia['atención'].value_counts()
# Out:
# Casa          11
# Recuperado     2
# Name: atención, dtype: int64

# %%
eluniversal= pd.read_csv('res/eluniversal_2020_04_24_articles.csv', encoding='ISO-8859–1')
eluniversal
# Out:
#                                                   body  \
# 0    \r\nPor Arlequín\r\nPor si nos hicieran falta ...
# 1    \r\n\r\nGinebra. Las muertes causadas por el ...
# 2    TOLUCA. Luego de los enfrentamientos que el m...
# 3    \r\n\r\nHace una semana, nos recuerdan, el pre...
# 4    \r\nEvanescence anuncian su primer álbum de nu...
# ..                                                 ...
# 139  \r\n\r\nMéxico vive tiempos complicados. Estam...
# 140  \r\n\r\nEn las redes sociales circula, a modo ...
# 141  \r\nCon el fin de impulsar la medida de protec...
# 142  En el historial delictivo de Jovan García hay ...
# 143  \r\n\r\nA toda velocidad, Francisco Gurría y s...
#
#                                                  title  \
# 0                                 El Rockstar de la 4T
# 1          Los asilos, trampas mortales ante Covid-19
# 2                                                  NaN
# 3                El equipo Eliot Ness de López Obrador
# ...

# %%
# 1 añadir newapaper_uid al dataFrame

eluniversal['nwespaper_uid'] = 'el universal'
eluniversal
# Out:
#                                                   body  \
# 0    \r\nPor Arlequín\r\nPor si nos hicieran falta ...
# 1    \r\n\r\nGinebra. Las muertes causadas por el ...
# 2    TOLUCA. Luego de los enfrentamientos que el m...
# 3    \r\n\r\nHace una semana, nos recuerdan, el pre...
# 4    \r\nEvanescence anuncian su primer álbum de nu...
# ..                                                 ...
# 139  \r\n\r\nMéxico vive tiempos complicados. Estam...
# 140  \r\n\r\nEn las redes sociales circula, a modo ...
# 141  \r\nCon el fin de impulsar la medida de protec...
# 142  En el historial delictivo de Jovan García hay ...
# 143  \r\n\r\nA toda velocidad, Francisco Gurría y s...
#
#                                                  title  \
# 0                                 El Rockstar de la 4T
# 1          Los asilos, trampas mortales ante Covid-19
# 2                                                  NaN
# 3                El equipo Eliot Ness de López Obrador
# ...

# %%
# 2 obtener el host
from urllib.parse import urlparse

eluniversal['host'] = eluniversal['url'].apply(lambda url: urlparse(url).netloc)
eluniversal
# Out:
#                                                   body  \
# 0    \r\nPor Arlequín\r\nPor si nos hicieran falta ...
# 1    \r\n\r\nGinebra. Las muertes causadas por el ...
# 2    TOLUCA. Luego de los enfrentamientos que el m...
# 3    \r\n\r\nHace una semana, nos recuerdan, el pre...
# 4    \r\nEvanescence anuncian su primer álbum de nu...
# ..                                                 ...
# 139  \r\n\r\nMéxico vive tiempos complicados. Estam...
# 140  \r\n\r\nEn las redes sociales circula, a modo ...
# 141  \r\nCon el fin de impulsar la medida de protec...
# 142  En el historial delictivo de Jovan García hay ...
# 143  \r\n\r\nA toda velocidad, Francisco Gurría y s...
#
#                                                  title  \
# 0                                 El Rockstar de la 4T
# 1          Los asilos, trampas mortales ante Covid-19
# 2                                                  NaN
# 3                El equipo Eliot Ness de López Obrador
# ...

# %%
eluniversal['host'].value_counts()
# Out:
# www.eluniversal.com.mx         86
# www.viveusa.mx                 13
# de10.com.mx                     7
# www.eluniversalqueretaro.mx     6
# oaxaca.eluniversal.com.mx       6
#                                ..
# www.unionjalisco.mx             3
# www.unionedomex.mx              3
# www.unionyucatan.mx             2
# www.unioncdmx.mx                1
# www.clubeluniversal.mx          1
# Name: host, Length: 14, dtype: int64

# %%
# 3. Rellenar datos faltantes
import re

missing_tittles_mask = eluniversal['title'].isna()

missing_titles=(eluniversal[missing_tittles_mask]['url']
                .str.extract(r'(?P<missing_titles>[^/]+)$')
                .applymap(lambda title: title.split('-'))
                .applymap(lambda title_word_list: ' '.join(title_word_list))
)

missing_titles
# Out:
#                                         missing_titles
# 2    atoran el huevotes peligroso lider de ambulant...
# 6    personas que estan en grupos de riesgo ante el...
# 15   heredera de disney enfurece por despidos tempo...
# 16                                       suscripciones
# 19   como el sol y la humedad ayudan eliminar el co...
# ..                                                 ...
# 120  secretaria de salud explica medidas para despe...
# 122  el es el musculoso hijo ilegitimo de arnold sc...
# 128  10 consejos para depilarte en casa como una pr...
# 131  melania trump tan fuerte e hieratica como amab...
# 142  asaltante con experiencia esta muy grave tras ...
#
# [26 rows x 1 columns]

# %%
# 4. AÑADIR UID A LAS FILAS
import hashlib

uids = (eluniversal
        .apply(lambda row: hashlib.md5(bytes(row['url'].encode())) , axis=1)
        .apply(lambda hash_object: hash_object.hexdigest())
)

eluniversal['uids'] = uids
eluniversal.set_index('uids', inplace=True)
eluniversal
# Out:
#                                                                                body  \
# uids
# 6fdd430fc84200bac3628d054d2818fd  \r\nPor Arlequín\r\nPor si nos hicieran falta ...
# 32f2d611b43d265f3dfa1bb25b4b9ade  \r\n\r\nGinebra. Las muertes causadas por el ...
# 865518353fb51b8d6d3b913bb5d1aea0  TOLUCA. Luego de los enfrentamientos que el m...
# 691bc1e8f75ddda21cfbe7ba495812e4  \r\n\r\nHace una semana, nos recuerdan, el pre...
# 4992b5b32ae2a021daec4f9e5608235b  \r\nEvanescence anuncian su primer álbum de nu...
# ...                                                                             ...
# 4b33fb9fc3a626a456721208cb419cf4  \r\n\r\nMéxico vive tiempos complicados. Estam...
# 927224685012110a3a7d25418cb602f0  \r\n\r\nEn las redes sociales circula, a modo ...
# f521aaec8ca5eee43bd113d0a40ae718  \r\nCon el fin de impulsar la medida de protec...
# 7ba1a5c5a7fea5ac226e7b32389dd7b7  En el historial delictivo de Jovan García hay ...
# ...

# %%
stripped_body = (eluniversal
                .apply(lambda row: row['body'], axis=1)
                .apply(lambda body:list(body))
                .apply(lambda letters: list(map(lambda letter: letter.replace('\n',' '),letters)))
                .apply(lambda letters: list(map(lambda letter: letter.replace('\r',''),letters)))
                .apply(lambda letters: ''.join(letters))
                )

stripped_body
# Out:
# uids
# 6fdd430fc84200bac3628d054d2818fd     Por Arlequín Por si nos hicieran falta malas ...
# 32f2d611b43d265f3dfa1bb25b4b9ade      Ginebra. Las muertes causadas por el corona...
# 865518353fb51b8d6d3b913bb5d1aea0    TOLUCA. Luego de los enfrentamientos que el m...
# 691bc1e8f75ddda21cfbe7ba495812e4      Hace una semana, nos recuerdan, el president...
# 4992b5b32ae2a021daec4f9e5608235b     Evanescence anuncian su primer álbum de nueva...
#                                                           ...
# 4b33fb9fc3a626a456721208cb419cf4      México vive tiempos complicados. Estamos ent...
# 927224685012110a3a7d25418cb602f0      En las redes sociales circula, a modo de bro...
# f521aaec8ca5eee43bd113d0a40ae718     Con el fin de impulsar la medida de protecció...
# 7ba1a5c5a7fea5ac226e7b32389dd7b7    En el historial delictivo de Jovan García hay ...
# bafa7259c096b210aace06d8f893b857      A toda velocidad, Francisco Gurría y sus com...
# Length: 144, dtype: object

# %%
# 6 tokenizar el titulo y el body

import nltk
from nltk.corpus import stopwords

nltk.download('punk')
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Error loading punk: Package 'punk' not found in index
# [nltk_data] Downloading package stopwords to C:\Users\Fredy
# [nltk_data]     Orozco\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Fredy
# [nltk_data]     Orozco\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('spanish'))

def tokenize_column(df, column_name):
    return (df
            .dropna()
            .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
            .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
            .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
            .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
            .apply(lambda valid_wordlist: len(valid_wordlist))
            
           )
eluniversal['n_tokens_title'] = tokenize_column(eluniversal, 'body')
eluniversal
# Out:
#                                                                                body  \
# uids
# 6fdd430fc84200bac3628d054d2818fd  \r\nPor Arlequín\r\nPor si nos hicieran falta ...
# 32f2d611b43d265f3dfa1bb25b4b9ade  \r\n\r\nGinebra. Las muertes causadas por el ...
# 865518353fb51b8d6d3b913bb5d1aea0  TOLUCA. Luego de los enfrentamientos que el m...
# 691bc1e8f75ddda21cfbe7ba495812e4  \r\n\r\nHace una semana, nos recuerdan, el pre...
# 4992b5b32ae2a021daec4f9e5608235b  \r\nEvanescence anuncian su primer álbum de nu...
# ...                                                                             ...
# 4b33fb9fc3a626a456721208cb419cf4  \r\n\r\nMéxico vive tiempos complicados. Estam...
# 927224685012110a3a7d25418cb602f0  \r\n\r\nEn las redes sociales circula, a modo ...
# f521aaec8ca5eee43bd113d0a40ae718  \r\nCon el fin de impulsar la medida de protec...
# 7ba1a5c5a7fea5ac226e7b32389dd7b7  En el historial delictivo de Jovan García hay ...
# ...

# %%
# 8. eliminar duplicado
eluniversal['title'].value_counts()
# Out:
# Suman en México mil 221 fallecidos por Covid-19, con 12,872 contagios                                       1
# Coronavirus: Cuándo empieza y cuánto dura la cuarentena en México                                           1
# En la Bundesliga pagarían millonada al América por Bruno Valdez                                             1
# Con estos videos, Sectur le recuerda al mundo los atractivos de México                                      1
# Laboratorio chino experimenta en monos con éxito vacuna contra Covid-19                                     1
#                                                                                                            ..
# La Guerrilla, barra del Atlético de San Luis dona material de protección para personal médico del IMSS    1
# Alfonso Romo: solo, enojado y decepcionado                                                                  1
# ...

# %%
eluniversal.drop_duplicates(subset=['title'], keep = 'first', inplace=True)
eluniversal
# Out:
#                                                                                body  \
# uids
# 6fdd430fc84200bac3628d054d2818fd  \r\nPor Arlequín\r\nPor si nos hicieran falta ...
# 32f2d611b43d265f3dfa1bb25b4b9ade  \r\n\r\nGinebra. Las muertes causadas por el ...
# 865518353fb51b8d6d3b913bb5d1aea0  TOLUCA. Luego de los enfrentamientos que el m...
# 691bc1e8f75ddda21cfbe7ba495812e4  \r\n\r\nHace una semana, nos recuerdan, el pre...
# 4992b5b32ae2a021daec4f9e5608235b  \r\nEvanescence anuncian su primer álbum de nu...
# ...                                                                             ...
# 3155918a11ad281264b54edc022f2a0a  \r\n\r\nAnoche, sin precisar recortes o aument...
# 4b33fb9fc3a626a456721208cb419cf4  \r\n\r\nMéxico vive tiempos complicados. Estam...
# 927224685012110a3a7d25418cb602f0  \r\n\r\nEn las redes sociales circula, a modo ...
# f521aaec8ca5eee43bd113d0a40ae718  \r\nCon el fin de impulsar la medida de protec...
# ...

# %%
clean_eluniversal =pd.read_csv('res/clean_eluniversal_2020_04_24_articles.csv')
clean_otro = pd.read_csv('res/clean_washingtonpost_20_04_26_aticles.csv')
clean_eluniversal
# Out:
#                                  uids  \
# 0    6fdd430fc84200bac3628d054d2818fd
# 1    32f2d611b43d265f3dfa1bb25b4b9ade
# 2    865518353fb51b8d6d3b913bb5d1aea0
# 3    691bc1e8f75ddda21cfbe7ba495812e4
# 4    4992b5b32ae2a021daec4f9e5608235b
# ..                                ...
# 139  4b33fb9fc3a626a456721208cb419cf4
# 140  927224685012110a3a7d25418cb602f0
# 141  f521aaec8ca5eee43bd113d0a40ae718
# 142  7ba1a5c5a7fea5ac226e7b32389dd7b7
# 143  bafa7259c096b210aace06d8f893b857
#
#                                                   body  \
# 0     Por Arlequín Por si nos hicieran falta malas ...
# 1      Ginebra. Las muertes causadas por el corona...
# 2    TOLUCA. Luego de los enfrentamientos que el m...
# 3      Hace una semana, nos recuerdan, el president...
# 4     Evanescence anuncian su primer álbum de nueva...
# ..                                                 ...
# 139    México vive tiempos complicados. Estamos ent...
# ...

# %%
clean_otro
# Out:
#                                uids  \
# 0  cbd02f272a424b5fa771368b6c48ff26
# 1  f8f903d22759f6a2deb26295a0bde7fe
# 2  88228b048bd6ff0eab65be4ad197517f
# 3  4ce6a0d1171f3a353817cbcc68d6ecaa
# 4  1c3b44f22296bf2521600f900209c398
# 5  92aaf400ba09d5f0024e8c429f20c3b1
# 6  ee92c93654ef50f2f077ab13dd82cb29
# 7  80432ad4196cc34ac215d4b8a12e0216
# 8  34f5b88cddb1b4660ea474efb931f8a8
#
#                                                 body  \
# 0  These photos explore how rising sea levels are...
# 1  You know how to make guacamole, so here are 7 ...
# 2  For black folks, its like a setup: Are you t...
# 3  How to secure a refund for a flight canceled d...
# 4  Animal cams offer a peek at a penguin or prima...
# 5  How to think about planning travel this summer...
# 6  In these states, pandemic crisis response incl...
# 7  For the first time ever, DoubleTree has releas...
# 8  This Peruvian take on beans and rice will remi...
#
#                                                title  \
# ...

# %%
clean_eluniversal.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count      144.000000     144.000000
# mean         5.826389     242.909722
# std          1.775237     138.069705
# min          1.000000       9.000000
# 25%          5.000000     136.250000
# 50%          6.000000     211.500000
# 75%          7.000000     335.000000
# max         10.000000     654.000000

# %%
clean_otro.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count        9.000000       9.000000
# mean      1153.111111      12.888889
# std       1068.824055       2.472066
# min        364.000000       9.000000
# 25%        551.000000      11.000000
# 50%        831.000000      13.000000
# 75%        893.000000      14.000000
# max       3730.000000      16.000000

# %%
clean_eluniversal.loc[clean_eluniversal['n_tokens_title'] == 1]
# Out:
#                                 uids  \
# 0   6fdd430fc84200bac3628d054d2818fd
# 16  3e542ff3beadc7730bbe798190f3cf39
# 54  3ddd3ab4b9ba4bc060ee1d381f901aa5
#
#                                                  body  \
# 0    Por Arlequín Por si nos hicieran falta malas ...
# 16   Toggle navigation  SuscripcionesEl Universal ...
# 54    La sociedad global vive una experiencia sin ...
#
#                              title  \
# 0             El Rockstar de la 4T
# 16                   suscripciones
# 54  El Covid-19 y el sentido común
#
#                                                   url newspaper_uid  \
# 0   https://www.eluniversal.com.mx/opinion/arlequi...   eluniversal
# 16  https://www.clubeluniversal.mx/content/suscrip...   eluniversal
# 54  https://www.eluniversal.com.mx/opinion/marcela...   eluniversal
#
#                       host  n_tokens_title  n_tokens_body
# 0   www.eluniversal.com.mx               1            540
# ...

# %%
# %matplotlib inline
clean_eluniversal['n_tokens_body'].plot(style='k')
clean_otro['n_tokens_title'].plot(style='r.')

# %%
all_newspaper = pd.concat([clean_eluniversal, clean_otro])
grouped = all_newspaper.groupby('newspaper_uid')
grouped.hist()
# Out:
# newspaper_uid
# eluniversal       [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# washingtonpost    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# dtype: object

# %%
grouped['n_tokens_body'].agg(['min','mean','max'])
# Out:
#                 min        mean  max
# newspaper_uid
# eluniversal       9  242.909722  654
# washingtonpost    9   12.888889   16
